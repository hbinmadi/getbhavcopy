# %% [markdown]
# <a href="https://colab.research.google.com/github/hbinmadi/getbhavcopy/blob/master/NIFTY_ML_LEARN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in /usr/local/lib/python3.7/dist-packages (0.8.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.23.0)
# Requirement already satisfied: requests-html in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (6.0.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.19.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.2.5)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.7/dist-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.2.6)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: importlib-metadata<3.0.0,>=2.1.1; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (2.1.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.60.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.1.0)
# Requirement already satisfied: websockets<9.0,>=8.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<3.0.0,>=2.1.1; python_version < "3.8"->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.4.1)

# %%
#!/usr/bin/env python
# coding: utf-8

# In[44]:

import os
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from yahoo_fin import stock_info as si
from collections import deque
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(allow_growth=True))
sess = tf.compat.v1.Session(config=config)



# In[45]:


# set seed, so we can get the same results after rerunning several times
np.random.seed(314)
tf.random.set_seed(314)
random.seed(314)


# In[46]:


def shuffle_in_unison(a, b):
    # shuffle two arrays in the same way
    state = np.random.get_state()
    np.random.shuffle(a)
    np.random.set_state(state)
    np.random.shuffle(b)

def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, split_by_date=True,
                test_size=0.2, feature_columns=['adjclose', 'volume', 'open', 'high', 'low']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the dataset (both training & testing), default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        split_by_date (bool): whether we split the dataset into training/testing by date, setting it 
            to False will split datasets in a random way
        test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yahoo_fin library
        df = si.get_data(ticker)
        df = df[df.volume.notnull()]
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    # this will contain all the elements we want to return from this function
    result = {}
    # we will also return the original dataframe itself
    result['df'] = df.copy()
    # make sure that the passed feature_columns exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    # add date as a column
    if "date" not in df.columns:
        df["date"] = df.index
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['adjclose'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns + ["date"]].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices that are not available in the dataset
    last_sequence = list([s[:len(feature_columns)] for s in sequences]) + list(last_sequence)
    last_sequence = np.array(last_sequence).astype(np.float32)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    if split_by_date:
        # split the dataset into training & testing sets by date (not randomly splitting)
        train_samples = int((1 - test_size) * len(X))
        result["X_train"] = X[:train_samples]
        result["y_train"] = y[:train_samples]
        result["X_test"]  = X[train_samples:]
        result["y_test"]  = y[train_samples:]
        if shuffle:
            # shuffle the datasets for training (if shuffle parameter is set)
            shuffle_in_unison(result["X_train"], result["y_train"])
            shuffle_in_unison(result["X_test"], result["y_test"])
    else:    
        # split the dataset randomly
        result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, 
                                                                                test_size=test_size, shuffle=shuffle)
    # get the list of test set dates
    dates = result["X_test"][:, -1, -1]
    # retrieve test features from the original dataframe
    result["test_df"] = result["df"].loc[dates]
    # remove duplicated dates in the testing dataframe
    result["test_df"] = result["test_df"][~result["test_df"].index.duplicated(keep='first')]
    # remove dates from the training/testing sets & convert to float32
    result["X_train"] = result["X_train"][:, :, :len(feature_columns)].astype(np.float32)
    result["X_test"] = result["X_test"][:, :, :len(feature_columns)].astype(np.float32)
    return result


# In[47]:


def create_model(sequence_length, n_features, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), batch_input_shape=(None, sequence_length, n_features)))
            else:
                model.add(cell(units, return_sequences=True, batch_input_shape=(None, sequence_length, n_features)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model


# In[48]:


import os
import time
from tensorflow.keras.layers import LSTM

# Window size or the sequence length
N_STEPS = 50
# Lookup step, 1 is the next day
LOOKUP_STEP = 15
# whether to scale feature columns & output price as well
SCALE = True
scale_str = f"sc-{int(SCALE)}"
# whether to shuffle the dataset
SHUFFLE = True
shuffle_str = f"sh-{int(SHUFFLE)}"
# whether to split the training/testing set by date
SPLIT_BY_DATE = False
split_by_date_str = f"sbd-{int(SPLIT_BY_DATE)}"
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["adjclose", "volume", "open", "high", "low"]
# date now
date_now = time.strftime("%Y-%m-%d")
### model parameters
N_LAYERS = 2
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 256
# 40% dropout
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = False
### training parameters
# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS =10000
# Amazon stock market
ticker = "^NSEI"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{shuffle_str}-{scale_str}-{split_by_date_str}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"


# In[49]:


# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")


# In[ ]:


# load the data
data = load_data(ticker, N_STEPS, scale=SCALE, split_by_date=SPLIT_BY_DATE, 
                shuffle=SHUFFLE, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, 
                feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv(ticker_data_filename)

#remove rows without volume
# import csv
# with open(ticker_data_filename, 'rb') as inp, open(ticker_data_filename, 'wb') as out:
#     writer = csv.writer(out)
#     for row in csv.reader(inp):
#         if row[6] != "0":
#             writer.writerow(row)
            
# construct the model
model = create_model(N_STEPS, len(FEATURE_COLUMNS), loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
# train the model and save the weights whenever we see 
# a new optimal model using ModelCheckpoint
history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)
model.save("D:/mymodel.hdf5")

# In[ ]:





# In[36]:


import matplotlib.pyplot as plt

def plot_graph(test_df):
    """
    This function plots true close price along with predicted close price
    with blue and red colors respectively
    """
    plt.plot(test_df[f'true_adjclose_{LOOKUP_STEP}'], c='b')
    plt.plot(test_df[f'adjclose_{LOOKUP_STEP}'], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()


# In[19]:


def get_final_df(model, data):
    """
    This function takes the `model` and `data` dict to 
    construct a final dataframe that includes the features along 
    with true and predicted prices of the testing dataset
    """
    # if predicted future price is higher than the current, 
    # then calculate the true future price minus the current price, to get the buy profit
    buy_profit  = lambda current, true_future, pred_future: true_future - current if pred_future > current else 0
    # if the predicted future price is lower than the current price,
    # then subtract the true future price from the current price
    sell_profit = lambda current, true_future, pred_future: current - true_future if pred_future < current else 0
    X_test = data["X_test"]
    y_test = data["y_test"]
    # perform prediction and get prices
    y_pred = model.predict(X_test)
    if SCALE:
        y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
        y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    test_df = data["test_df"]
    # add predicted future prices to the dataframe
    test_df[f"adjclose_{LOOKUP_STEP}"] = y_pred
    # add true future prices to the dataframe
    test_df[f"true_adjclose_{LOOKUP_STEP}"] = y_test
    # sort the dataframe by date
    test_df.sort_index(inplace=True)
    final_df = test_df
    # add the buy profit column
    final_df["buy_profit"] = list(map(buy_profit, 
                                    final_df["adjclose"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    # add the sell profit column
    final_df["sell_profit"] = list(map(sell_profit, 
                                    final_df["adjclose"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    return final_df


# In[20]:


def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    if SCALE:
        predicted_price = data["column_scaler"]["adjclose"].inverse_transform(prediction)[0][0]
    else:
        predicted_price = prediction[0][0]
    return predicted_price


# In[37]:


# load optimal model weights from results folder
model_path = os.path.join("results", model_name) + ".h5"
model.load_weights(model_path)


# In[38]:


# evaluate the model
loss, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
if SCALE:
    mean_absolute_error = data["column_scaler"]["adjclose"].inverse_transform([[mae]])[0][0]
else:
    mean_absolute_error = mae


# In[39]:


# get the final dataframe for the testing set
final_df = get_final_df(model, data)


# In[40]:


# predict the future price
future_price = predict(model, data)


# In[41]:


# we calculate the accuracy by counting the number of positive profits
accuracy_score = (len(final_df[final_df['sell_profit'] > 0]) + len(final_df[final_df['buy_profit'] > 0])) / len(final_df)
# calculating total buy & sell profit
total_buy_profit  = final_df["buy_profit"].sum()
total_sell_profit = final_df["sell_profit"].sum()
# total profit by adding sell & buy together
total_profit = total_buy_profit + total_sell_profit
# dividing total profit by number of testing samples (number of trades)
profit_per_trade = total_profit / len(final_df)


# In[42]:


# printing metrics
print(f"Future price after {LOOKUP_STEP} days is {future_price:.2f}$")
print(f"{LOSS} loss:", loss)
print("Mean Absolute Error:", mean_absolute_error)
print("Accuracy score:", accuracy_score)
print("Total buy profit:", total_buy_profit)
print("Total sell profit:", total_sell_profit)
print("Total profit:", total_profit)
print("Profit per trade:", profit_per_trade)


# In[ ]:
# Out:
# Epoch 1/10000
# 41/41 [==============================] - 5s 53ms/step - loss: 0.0188 - mean_absolute_error: 0.1244 - val_loss: 7.1440e-04 - val_mean_absolute_error: 0.0260
#
# Epoch 00001: val_loss improved from inf to 0.00071, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 2/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0371 - val_loss: 5.6238e-04 - val_mean_absolute_error: 0.0224
#
# Epoch 00002: val_loss improved from 0.00071 to 0.00056, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 3/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0354 - val_loss: 5.6171e-04 - val_mean_absolute_error: 0.0226
#
# Epoch 00003: val_loss improved from 0.00056 to 0.00056, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 4/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0342 - val_loss: 5.6001e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00004: val_loss improved from 0.00056 to 0.00056, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 5/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0010 - mean_absolute_error: 0.0325 - val_loss: 5.6692e-04 - val_mean_absolute_error: 0.0231
#
# Epoch 00005: val_loss did not improve from 0.00056
# Epoch 6/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0329 - val_loss: 5.7146e-04 - val_mean_absolute_error: 0.0235
#
# Epoch 00006: val_loss did not improve from 0.00056
# Epoch 7/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0338 - val_loss: 6.1667e-04 - val_mean_absolute_error: 0.0232
#
# Epoch 00007: val_loss did not improve from 0.00056
# Epoch 8/10000
# 41/41 [==============================] - 1s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0332 - val_loss: 5.4415e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00008: val_loss improved from 0.00056 to 0.00054, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 9/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0375 - val_loss: 6.6275e-04 - val_mean_absolute_error: 0.0239
#
# Epoch 00009: val_loss did not improve from 0.00054
# Epoch 10/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0348 - val_loss: 5.3659e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00010: val_loss improved from 0.00054 to 0.00054, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 11/10000
# 41/41 [==============================] - 1s 15ms/step - loss: 9.4595e-04 - mean_absolute_error: 0.0317 - val_loss: 6.2928e-04 - val_mean_absolute_error: 0.0257
#
# Epoch 00011: val_loss did not improve from 0.00054
# Epoch 12/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0326 - val_loss: 5.5747e-04 - val_mean_absolute_error: 0.0232
#
# Epoch 00012: val_loss did not improve from 0.00054
# Epoch 13/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0010 - mean_absolute_error: 0.0324 - val_loss: 8.4563e-04 - val_mean_absolute_error: 0.0315
#
# Epoch 00013: val_loss did not improve from 0.00054
# Epoch 14/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0010 - mean_absolute_error: 0.0328 - val_loss: 6.1994e-04 - val_mean_absolute_error: 0.0252
#
# Epoch 00014: val_loss did not improve from 0.00054
# Epoch 15/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.8512e-04 - mean_absolute_error: 0.0314 - val_loss: 5.5293e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00015: val_loss did not improve from 0.00054
# Epoch 16/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0328 - val_loss: 9.7138e-04 - val_mean_absolute_error: 0.0351
#
# Epoch 00016: val_loss did not improve from 0.00054
# Epoch 17/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0336 - val_loss: 5.4109e-04 - val_mean_absolute_error: 0.0227
#
# Epoch 00017: val_loss did not improve from 0.00054
# Epoch 18/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 9.5451e-04 - mean_absolute_error: 0.0310 - val_loss: 5.7751e-04 - val_mean_absolute_error: 0.0223
#
# Epoch 00018: val_loss did not improve from 0.00054
# Epoch 19/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.9477e-04 - mean_absolute_error: 0.0308 - val_loss: 5.9707e-04 - val_mean_absolute_error: 0.0248
#
# Epoch 00019: val_loss did not improve from 0.00054
# Epoch 20/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 9.6375e-04 - mean_absolute_error: 0.0327 - val_loss: 5.2709e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00020: val_loss improved from 0.00054 to 0.00053, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 21/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 9.7603e-04 - mean_absolute_error: 0.0322 - val_loss: 5.3681e-04 - val_mean_absolute_error: 0.0224
#
# Epoch 00021: val_loss did not improve from 0.00053
# Epoch 22/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.7846e-04 - mean_absolute_error: 0.0306 - val_loss: 5.2084e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00022: val_loss improved from 0.00053 to 0.00052, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 23/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.9942e-04 - mean_absolute_error: 0.0308 - val_loss: 5.4334e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00023: val_loss did not improve from 0.00052
# Epoch 24/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.8136e-04 - mean_absolute_error: 0.0301 - val_loss: 5.2127e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00024: val_loss did not improve from 0.00052
# Epoch 25/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.6243e-04 - mean_absolute_error: 0.0304 - val_loss: 5.1765e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00025: val_loss improved from 0.00052 to 0.00052, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 26/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.2306e-04 - mean_absolute_error: 0.0294 - val_loss: 5.6211e-04 - val_mean_absolute_error: 0.0222
#
# Epoch 00026: val_loss did not improve from 0.00052
# Epoch 27/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.6140e-04 - mean_absolute_error: 0.0305 - val_loss: 5.8543e-04 - val_mean_absolute_error: 0.0244
#
# Epoch 00027: val_loss did not improve from 0.00052
# Epoch 28/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0010 - mean_absolute_error: 0.0325 - val_loss: 5.3451e-04 - val_mean_absolute_error: 0.0222
#
# Epoch 00028: val_loss did not improve from 0.00052
# Epoch 29/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.0918e-04 - mean_absolute_error: 0.0292 - val_loss: 5.9188e-04 - val_mean_absolute_error: 0.0248
#
# Epoch 00029: val_loss did not improve from 0.00052
# Epoch 30/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 9.2394e-04 - mean_absolute_error: 0.0310 - val_loss: 7.1640e-04 - val_mean_absolute_error: 0.0280
#
# Epoch 00030: val_loss did not improve from 0.00052
# Epoch 31/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.2490e-04 - mean_absolute_error: 0.0297 - val_loss: 5.5034e-04 - val_mean_absolute_error: 0.0233
#
# Epoch 00031: val_loss did not improve from 0.00052
# Epoch 32/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.9997e-04 - mean_absolute_error: 0.0294 - val_loss: 5.6514e-04 - val_mean_absolute_error: 0.0223
#
# Epoch 00032: val_loss did not improve from 0.00052
# Epoch 33/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 9.7339e-04 - mean_absolute_error: 0.0312 - val_loss: 6.7657e-04 - val_mean_absolute_error: 0.0271
#
# Epoch 00033: val_loss did not improve from 0.00052
# Epoch 34/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.2521e-04 - mean_absolute_error: 0.0302 - val_loss: 5.5474e-04 - val_mean_absolute_error: 0.0222
#
# Epoch 00034: val_loss did not improve from 0.00052
# Epoch 35/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 9.5948e-04 - mean_absolute_error: 0.0306 - val_loss: 5.3543e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00035: val_loss did not improve from 0.00052
# Epoch 36/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.6033e-04 - mean_absolute_error: 0.0283 - val_loss: 5.1721e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00036: val_loss improved from 0.00052 to 0.00052, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 37/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.7310e-04 - mean_absolute_error: 0.0280 - val_loss: 5.5387e-04 - val_mean_absolute_error: 0.0220
#
# Epoch 00037: val_loss did not improve from 0.00052
# Epoch 38/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.7885e-04 - mean_absolute_error: 0.0291 - val_loss: 5.7096e-04 - val_mean_absolute_error: 0.0223
#
# Epoch 00038: val_loss did not improve from 0.00052
# Epoch 39/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.2493e-04 - mean_absolute_error: 0.0296 - val_loss: 5.4253e-04 - val_mean_absolute_error: 0.0233
#
# Epoch 00039: val_loss did not improve from 0.00052
# Epoch 40/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 9.2518e-04 - mean_absolute_error: 0.0304 - val_loss: 5.1437e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00040: val_loss improved from 0.00052 to 0.00051, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 41/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.9784e-04 - mean_absolute_error: 0.0302 - val_loss: 5.6709e-04 - val_mean_absolute_error: 0.0222
#
# Epoch 00041: val_loss did not improve from 0.00051
# Epoch 42/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.5101e-04 - mean_absolute_error: 0.0291 - val_loss: 8.3696e-04 - val_mean_absolute_error: 0.0319
#
# Epoch 00042: val_loss did not improve from 0.00051
# Epoch 43/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.9076e-04 - mean_absolute_error: 0.0293 - val_loss: 5.4574e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00043: val_loss did not improve from 0.00051
# Epoch 44/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.4843e-04 - mean_absolute_error: 0.0306 - val_loss: 5.3927e-04 - val_mean_absolute_error: 0.0230
#
# Epoch 00044: val_loss did not improve from 0.00051
# Epoch 45/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.1728e-04 - mean_absolute_error: 0.0290 - val_loss: 5.6594e-04 - val_mean_absolute_error: 0.0242
#
# Epoch 00045: val_loss did not improve from 0.00051
# Epoch 46/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.7762e-04 - mean_absolute_error: 0.0285 - val_loss: 5.1406e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00046: val_loss improved from 0.00051 to 0.00051, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 47/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.8275e-04 - mean_absolute_error: 0.0285 - val_loss: 6.0419e-04 - val_mean_absolute_error: 0.0250
#
# Epoch 00047: val_loss did not improve from 0.00051
# Epoch 48/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.1565e-04 - mean_absolute_error: 0.0294 - val_loss: 5.5760e-04 - val_mean_absolute_error: 0.0224
#
# Epoch 00048: val_loss did not improve from 0.00051
# Epoch 49/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.5971e-04 - mean_absolute_error: 0.0279 - val_loss: 6.2159e-04 - val_mean_absolute_error: 0.0255
#
# Epoch 00049: val_loss did not improve from 0.00051
# Epoch 50/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.0538e-04 - mean_absolute_error: 0.0287 - val_loss: 5.4795e-04 - val_mean_absolute_error: 0.0220
#
# Epoch 00050: val_loss did not improve from 0.00051
# Epoch 51/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.0588e-04 - mean_absolute_error: 0.0276 - val_loss: 5.8117e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00051: val_loss did not improve from 0.00051
# Epoch 52/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.0793e-04 - mean_absolute_error: 0.0285 - val_loss: 6.5931e-04 - val_mean_absolute_error: 0.0268
#
# Epoch 00052: val_loss did not improve from 0.00051
# Epoch 53/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.6863e-04 - mean_absolute_error: 0.0290 - val_loss: 5.1435e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00053: val_loss did not improve from 0.00051
# Epoch 54/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.6416e-04 - mean_absolute_error: 0.0281 - val_loss: 5.9924e-04 - val_mean_absolute_error: 0.0253
#
# Epoch 00054: val_loss did not improve from 0.00051
# Epoch 55/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.9927e-04 - mean_absolute_error: 0.0285 - val_loss: 6.4170e-04 - val_mean_absolute_error: 0.0268
#
# Epoch 00055: val_loss did not improve from 0.00051
# Epoch 56/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.6916e-04 - mean_absolute_error: 0.0280 - val_loss: 5.0456e-04 - val_mean_absolute_error: 0.0214
#
# Epoch 00056: val_loss improved from 0.00051 to 0.00050, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 57/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.2452e-04 - mean_absolute_error: 0.0268 - val_loss: 5.2395e-04 - val_mean_absolute_error: 0.0226
#
# Epoch 00057: val_loss did not improve from 0.00050
# Epoch 58/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.0888e-04 - mean_absolute_error: 0.0280 - val_loss: 5.7280e-04 - val_mean_absolute_error: 0.0242
#
# Epoch 00058: val_loss did not improve from 0.00050
# Epoch 59/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.2204e-04 - mean_absolute_error: 0.0270 - val_loss: 5.2506e-04 - val_mean_absolute_error: 0.0226
#
# Epoch 00059: val_loss did not improve from 0.00050
# Epoch 60/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.5439e-04 - mean_absolute_error: 0.0262 - val_loss: 5.5448e-04 - val_mean_absolute_error: 0.0221
#
# Epoch 00060: val_loss did not improve from 0.00050
# Epoch 61/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.3912e-04 - mean_absolute_error: 0.0261 - val_loss: 5.0913e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00061: val_loss did not improve from 0.00050
# Epoch 62/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.6528e-04 - mean_absolute_error: 0.0266 - val_loss: 5.1186e-04 - val_mean_absolute_error: 0.0214
#
# Epoch 00062: val_loss did not improve from 0.00050
# Epoch 63/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.2224e-04 - mean_absolute_error: 0.0275 - val_loss: 5.0766e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00063: val_loss did not improve from 0.00050
# Epoch 64/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.4231e-04 - mean_absolute_error: 0.0258 - val_loss: 5.2423e-04 - val_mean_absolute_error: 0.0225
#
# Epoch 00064: val_loss did not improve from 0.00050
# Epoch 65/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.4562e-04 - mean_absolute_error: 0.0268 - val_loss: 5.3503e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00065: val_loss did not improve from 0.00050
# Epoch 66/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.0509e-04 - mean_absolute_error: 0.0256 - val_loss: 5.1167e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00066: val_loss did not improve from 0.00050
# Epoch 67/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.7213e-04 - mean_absolute_error: 0.0253 - val_loss: 5.1955e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00067: val_loss did not improve from 0.00050
# Epoch 68/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.4800e-04 - mean_absolute_error: 0.0276 - val_loss: 5.0727e-04 - val_mean_absolute_error: 0.0214
#
# Epoch 00068: val_loss did not improve from 0.00050
# Epoch 69/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 8.2001e-04 - mean_absolute_error: 0.0287 - val_loss: 5.7968e-04 - val_mean_absolute_error: 0.0244
#
# Epoch 00069: val_loss did not improve from 0.00050
# Epoch 70/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.4490e-04 - mean_absolute_error: 0.0279 - val_loss: 5.4732e-04 - val_mean_absolute_error: 0.0235
#
# Epoch 00070: val_loss did not improve from 0.00050
# Epoch 71/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.2599e-04 - mean_absolute_error: 0.0266 - val_loss: 5.0850e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00071: val_loss did not improve from 0.00050
# Epoch 72/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.3399e-04 - mean_absolute_error: 0.0257 - val_loss: 6.3470e-04 - val_mean_absolute_error: 0.0243
#
# Epoch 00072: val_loss did not improve from 0.00050
# Epoch 73/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.9053e-04 - mean_absolute_error: 0.0283 - val_loss: 5.1867e-04 - val_mean_absolute_error: 0.0214
#
# Epoch 00073: val_loss did not improve from 0.00050
# Epoch 74/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.5318e-04 - mean_absolute_error: 0.0264 - val_loss: 5.3395e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00074: val_loss did not improve from 0.00050
# Epoch 75/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.7471e-04 - mean_absolute_error: 0.0277 - val_loss: 5.3002e-04 - val_mean_absolute_error: 0.0228
#
# Epoch 00075: val_loss did not improve from 0.00050
# Epoch 76/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.6715e-04 - mean_absolute_error: 0.0260 - val_loss: 5.2428e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00076: val_loss did not improve from 0.00050
# Epoch 77/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.8921e-04 - mean_absolute_error: 0.0249 - val_loss: 5.1526e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00077: val_loss did not improve from 0.00050
# Epoch 78/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.4339e-04 - mean_absolute_error: 0.0287 - val_loss: 5.1299e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00078: val_loss did not improve from 0.00050
# Epoch 79/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.2810e-04 - mean_absolute_error: 0.0256 - val_loss: 5.1819e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00079: val_loss did not improve from 0.00050
# Epoch 80/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.2915e-04 - mean_absolute_error: 0.0262 - val_loss: 5.1135e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00080: val_loss did not improve from 0.00050
# Epoch 81/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.0728e-04 - mean_absolute_error: 0.0264 - val_loss: 7.5416e-04 - val_mean_absolute_error: 0.0286
#
# Epoch 00081: val_loss did not improve from 0.00050
# Epoch 82/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.9796e-04 - mean_absolute_error: 0.0269 - val_loss: 5.3137e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00082: val_loss did not improve from 0.00050
# Epoch 83/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.7999e-04 - mean_absolute_error: 0.0269 - val_loss: 5.2463e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00083: val_loss did not improve from 0.00050
# Epoch 84/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.5423e-04 - mean_absolute_error: 0.0267 - val_loss: 5.2413e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00084: val_loss did not improve from 0.00050
# Epoch 85/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.4345e-04 - mean_absolute_error: 0.0262 - val_loss: 5.8282e-04 - val_mean_absolute_error: 0.0245
#
# Epoch 00085: val_loss did not improve from 0.00050
# Epoch 86/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.3530e-04 - mean_absolute_error: 0.0258 - val_loss: 4.9923e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00086: val_loss improved from 0.00050 to 0.00050, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 87/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.0070e-04 - mean_absolute_error: 0.0247 - val_loss: 5.3307e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00087: val_loss did not improve from 0.00050
# Epoch 88/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.8758e-04 - mean_absolute_error: 0.0269 - val_loss: 5.0327e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00088: val_loss did not improve from 0.00050
# Epoch 89/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.3118e-04 - mean_absolute_error: 0.0260 - val_loss: 5.3897e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00089: val_loss did not improve from 0.00050
# Epoch 90/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.7365e-04 - mean_absolute_error: 0.0264 - val_loss: 5.0826e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00090: val_loss did not improve from 0.00050
# Epoch 91/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.5118e-04 - mean_absolute_error: 0.0265 - val_loss: 5.0598e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00091: val_loss did not improve from 0.00050
# Epoch 92/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.2454e-04 - mean_absolute_error: 0.0263 - val_loss: 6.5212e-04 - val_mean_absolute_error: 0.0234
#
# Epoch 00092: val_loss did not improve from 0.00050
# Epoch 93/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.5617e-04 - mean_absolute_error: 0.0256 - val_loss: 5.1772e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00093: val_loss did not improve from 0.00050
# Epoch 94/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.1441e-04 - mean_absolute_error: 0.0258 - val_loss: 5.2961e-04 - val_mean_absolute_error: 0.0214
#
# Epoch 00094: val_loss did not improve from 0.00050
# Epoch 95/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.0048e-04 - mean_absolute_error: 0.0259 - val_loss: 4.9525e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00095: val_loss improved from 0.00050 to 0.00050, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 96/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.1322e-04 - mean_absolute_error: 0.0250 - val_loss: 5.4062e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00096: val_loss did not improve from 0.00050
# Epoch 97/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.6230e-04 - mean_absolute_error: 0.0244 - val_loss: 5.6226e-04 - val_mean_absolute_error: 0.0235
#
# Epoch 00097: val_loss did not improve from 0.00050
# Epoch 98/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.7048e-04 - mean_absolute_error: 0.0265 - val_loss: 4.9747e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00098: val_loss did not improve from 0.00050
# Epoch 99/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.9789e-04 - mean_absolute_error: 0.0270 - val_loss: 5.7450e-04 - val_mean_absolute_error: 0.0226
#
# Epoch 00099: val_loss did not improve from 0.00050
# Epoch 100/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.1110e-04 - mean_absolute_error: 0.0248 - val_loss: 5.0428e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00100: val_loss did not improve from 0.00050
# Epoch 101/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 7.0188e-04 - mean_absolute_error: 0.0269 - val_loss: 5.0383e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00101: val_loss did not improve from 0.00050
# Epoch 102/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.0019e-04 - mean_absolute_error: 0.0246 - val_loss: 4.9405e-04 - val_mean_absolute_error: 0.0214
#
# Epoch 00102: val_loss improved from 0.00050 to 0.00049, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 103/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.0828e-04 - mean_absolute_error: 0.0252 - val_loss: 5.1615e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00103: val_loss did not improve from 0.00049
# Epoch 104/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.8091e-04 - mean_absolute_error: 0.0247 - val_loss: 5.2001e-04 - val_mean_absolute_error: 0.0225
#
# Epoch 00104: val_loss did not improve from 0.00049
# Epoch 105/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.9925e-04 - mean_absolute_error: 0.0253 - val_loss: 6.2235e-04 - val_mean_absolute_error: 0.0254
#
# Epoch 00105: val_loss did not improve from 0.00049
# Epoch 106/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 7.1062e-04 - mean_absolute_error: 0.0270 - val_loss: 5.1593e-04 - val_mean_absolute_error: 0.0222
#
# Epoch 00106: val_loss did not improve from 0.00049
# Epoch 107/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.1557e-04 - mean_absolute_error: 0.0249 - val_loss: 5.9750e-04 - val_mean_absolute_error: 0.0247
#
# Epoch 00107: val_loss did not improve from 0.00049
# Epoch 108/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.3721e-04 - mean_absolute_error: 0.0256 - val_loss: 5.1727e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00108: val_loss did not improve from 0.00049
# Epoch 109/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.7551e-04 - mean_absolute_error: 0.0243 - val_loss: 5.0402e-04 - val_mean_absolute_error: 0.0220
#
# Epoch 00109: val_loss did not improve from 0.00049
# Epoch 110/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4469e-04 - mean_absolute_error: 0.0239 - val_loss: 4.9526e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00110: val_loss did not improve from 0.00049
# Epoch 111/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.2879e-04 - mean_absolute_error: 0.0253 - val_loss: 5.5563e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00111: val_loss did not improve from 0.00049
# Epoch 112/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.9538e-04 - mean_absolute_error: 0.0249 - val_loss: 4.9519e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00112: val_loss did not improve from 0.00049
# Epoch 113/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.5543e-04 - mean_absolute_error: 0.0254 - val_loss: 5.0379e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00113: val_loss did not improve from 0.00049
# Epoch 114/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.5046e-04 - mean_absolute_error: 0.0241 - val_loss: 5.0899e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00114: val_loss did not improve from 0.00049
# Epoch 115/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.0438e-04 - mean_absolute_error: 0.0251 - val_loss: 4.9227e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00115: val_loss improved from 0.00049 to 0.00049, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 116/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.5372e-04 - mean_absolute_error: 0.0244 - val_loss: 5.5090e-04 - val_mean_absolute_error: 0.0235
#
# Epoch 00116: val_loss did not improve from 0.00049
# Epoch 117/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.1878e-04 - mean_absolute_error: 0.0248 - val_loss: 4.9919e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00117: val_loss did not improve from 0.00049
# Epoch 118/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.6265e-04 - mean_absolute_error: 0.0244 - val_loss: 4.9734e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00118: val_loss did not improve from 0.00049
# Epoch 119/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.6392e-04 - mean_absolute_error: 0.0251 - val_loss: 5.4437e-04 - val_mean_absolute_error: 0.0234
#
# Epoch 00119: val_loss did not improve from 0.00049
# Epoch 120/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.4166e-04 - mean_absolute_error: 0.0257 - val_loss: 5.1192e-04 - val_mean_absolute_error: 0.0222
#
# Epoch 00120: val_loss did not improve from 0.00049
# Epoch 121/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.6504e-04 - mean_absolute_error: 0.0256 - val_loss: 4.9192e-04 - val_mean_absolute_error: 0.0209
#
# Epoch 00121: val_loss improved from 0.00049 to 0.00049, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 122/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.7178e-04 - mean_absolute_error: 0.0244 - val_loss: 5.0061e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00122: val_loss did not improve from 0.00049
# Epoch 123/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.8750e-04 - mean_absolute_error: 0.0259 - val_loss: 5.2062e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00123: val_loss did not improve from 0.00049
# Epoch 124/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.4004e-04 - mean_absolute_error: 0.0248 - val_loss: 5.7527e-04 - val_mean_absolute_error: 0.0223
#
# Epoch 00124: val_loss did not improve from 0.00049
# Epoch 125/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 7.9022e-04 - mean_absolute_error: 0.0276 - val_loss: 5.4383e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00125: val_loss did not improve from 0.00049
# Epoch 126/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.2264e-04 - mean_absolute_error: 0.0258 - val_loss: 4.9731e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00126: val_loss did not improve from 0.00049
# Epoch 127/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.0727e-04 - mean_absolute_error: 0.0249 - val_loss: 5.8211e-04 - val_mean_absolute_error: 0.0224
#
# Epoch 00127: val_loss did not improve from 0.00049
# Epoch 128/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.3168e-04 - mean_absolute_error: 0.0258 - val_loss: 5.4524e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00128: val_loss did not improve from 0.00049
# Epoch 129/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.3079e-04 - mean_absolute_error: 0.0249 - val_loss: 6.8962e-04 - val_mean_absolute_error: 0.0247
#
# Epoch 00129: val_loss did not improve from 0.00049
# Epoch 130/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.5678e-04 - mean_absolute_error: 0.0259 - val_loss: 4.9310e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00130: val_loss did not improve from 0.00049
# Epoch 131/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.4857e-04 - mean_absolute_error: 0.0246 - val_loss: 4.8593e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00131: val_loss improved from 0.00049 to 0.00049, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 132/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.5385e-04 - mean_absolute_error: 0.0244 - val_loss: 5.6159e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00132: val_loss did not improve from 0.00049
# Epoch 133/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4363e-04 - mean_absolute_error: 0.0244 - val_loss: 4.9025e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00133: val_loss did not improve from 0.00049
# Epoch 134/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.0122e-04 - mean_absolute_error: 0.0246 - val_loss: 4.8669e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00134: val_loss did not improve from 0.00049
# Epoch 135/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.7936e-04 - mean_absolute_error: 0.0244 - val_loss: 5.2510e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00135: val_loss did not improve from 0.00049
# Epoch 136/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.7892e-04 - mean_absolute_error: 0.0259 - val_loss: 5.1662e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00136: val_loss did not improve from 0.00049
# Epoch 137/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.9880e-04 - mean_absolute_error: 0.0246 - val_loss: 5.1475e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00137: val_loss did not improve from 0.00049
# Epoch 138/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.9087e-04 - mean_absolute_error: 0.0244 - val_loss: 5.5134e-04 - val_mean_absolute_error: 0.0234
#
# Epoch 00138: val_loss did not improve from 0.00049
# Epoch 139/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.2113e-04 - mean_absolute_error: 0.0258 - val_loss: 5.4558e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00139: val_loss did not improve from 0.00049
# Epoch 140/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.0399e-04 - mean_absolute_error: 0.0250 - val_loss: 5.0327e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00140: val_loss did not improve from 0.00049
# Epoch 141/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.3583e-04 - mean_absolute_error: 0.0257 - val_loss: 4.8483e-04 - val_mean_absolute_error: 0.0209
#
# Epoch 00141: val_loss improved from 0.00049 to 0.00048, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 142/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.6486e-04 - mean_absolute_error: 0.0242 - val_loss: 5.1101e-04 - val_mean_absolute_error: 0.0224
#
# Epoch 00142: val_loss did not improve from 0.00048
# Epoch 143/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.8002e-04 - mean_absolute_error: 0.0250 - val_loss: 5.1861e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00143: val_loss did not improve from 0.00048
# Epoch 144/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.6703e-04 - mean_absolute_error: 0.0241 - val_loss: 5.4856e-04 - val_mean_absolute_error: 0.0233
#
# Epoch 00144: val_loss did not improve from 0.00048
# Epoch 145/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.1730e-04 - mean_absolute_error: 0.0248 - val_loss: 6.6323e-04 - val_mean_absolute_error: 0.0236
#
# Epoch 00145: val_loss did not improve from 0.00048
# Epoch 146/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.9408e-04 - mean_absolute_error: 0.0264 - val_loss: 5.3531e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00146: val_loss did not improve from 0.00048
# Epoch 147/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.6541e-04 - mean_absolute_error: 0.0239 - val_loss: 4.8588e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00147: val_loss did not improve from 0.00048
# Epoch 148/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.6017e-04 - mean_absolute_error: 0.0239 - val_loss: 5.1566e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00148: val_loss did not improve from 0.00048
# Epoch 149/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.6640e-04 - mean_absolute_error: 0.0248 - val_loss: 6.1045e-04 - val_mean_absolute_error: 0.0250
#
# Epoch 00149: val_loss did not improve from 0.00048
# Epoch 150/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.8263e-04 - mean_absolute_error: 0.0249 - val_loss: 5.6087e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00150: val_loss did not improve from 0.00048
# Epoch 151/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.9567e-04 - mean_absolute_error: 0.0250 - val_loss: 4.8918e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00151: val_loss did not improve from 0.00048
# Epoch 152/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.2285e-04 - mean_absolute_error: 0.0237 - val_loss: 5.2226e-04 - val_mean_absolute_error: 0.0223
#
# Epoch 00152: val_loss did not improve from 0.00048
# Epoch 153/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.5979e-04 - mean_absolute_error: 0.0242 - val_loss: 4.8459e-04 - val_mean_absolute_error: 0.0208
#
# Epoch 00153: val_loss improved from 0.00048 to 0.00048, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 154/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.0877e-04 - mean_absolute_error: 0.0247 - val_loss: 4.9920e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00154: val_loss did not improve from 0.00048
# Epoch 155/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.8425e-04 - mean_absolute_error: 0.0246 - val_loss: 4.7951e-04 - val_mean_absolute_error: 0.0208
#
# Epoch 00155: val_loss improved from 0.00048 to 0.00048, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 156/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4472e-04 - mean_absolute_error: 0.0236 - val_loss: 4.9449e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00156: val_loss did not improve from 0.00048
# Epoch 157/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.5591e-04 - mean_absolute_error: 0.0238 - val_loss: 5.4110e-04 - val_mean_absolute_error: 0.0214
#
# Epoch 00157: val_loss did not improve from 0.00048
# Epoch 158/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.0724e-04 - mean_absolute_error: 0.0252 - val_loss: 4.8749e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00158: val_loss did not improve from 0.00048
# Epoch 159/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.4713e-04 - mean_absolute_error: 0.0242 - val_loss: 4.9364e-04 - val_mean_absolute_error: 0.0208
#
# Epoch 00159: val_loss did not improve from 0.00048
# Epoch 160/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.0202e-04 - mean_absolute_error: 0.0252 - val_loss: 5.0494e-04 - val_mean_absolute_error: 0.0222
#
# Epoch 00160: val_loss did not improve from 0.00048
# Epoch 161/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.0825e-04 - mean_absolute_error: 0.0253 - val_loss: 5.1726e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00161: val_loss did not improve from 0.00048
# Epoch 162/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.6402e-04 - mean_absolute_error: 0.0246 - val_loss: 5.3093e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00162: val_loss did not improve from 0.00048
# Epoch 163/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.4099e-04 - mean_absolute_error: 0.0237 - val_loss: 4.9573e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00163: val_loss did not improve from 0.00048
# Epoch 164/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.1277e-04 - mean_absolute_error: 0.0249 - val_loss: 6.3600e-04 - val_mean_absolute_error: 0.0236
#
# Epoch 00164: val_loss did not improve from 0.00048
# Epoch 165/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.2261e-04 - mean_absolute_error: 0.0252 - val_loss: 4.7950e-04 - val_mean_absolute_error: 0.0209
#
# Epoch 00165: val_loss improved from 0.00048 to 0.00048, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 166/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.7391e-04 - mean_absolute_error: 0.0241 - val_loss: 4.8394e-04 - val_mean_absolute_error: 0.0208
#
# Epoch 00166: val_loss did not improve from 0.00048
# Epoch 167/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.3138e-04 - mean_absolute_error: 0.0246 - val_loss: 5.0206e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00167: val_loss did not improve from 0.00048
# Epoch 168/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4686e-04 - mean_absolute_error: 0.0244 - val_loss: 4.8436e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00168: val_loss did not improve from 0.00048
# Epoch 169/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.4221e-04 - mean_absolute_error: 0.0235 - val_loss: 5.3239e-04 - val_mean_absolute_error: 0.0226
#
# Epoch 00169: val_loss did not improve from 0.00048
# Epoch 170/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 4.9553e-04 - mean_absolute_error: 0.0233 - val_loss: 4.9698e-04 - val_mean_absolute_error: 0.0220
#
# Epoch 00170: val_loss did not improve from 0.00048
# Epoch 171/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.9307e-04 - mean_absolute_error: 0.0249 - val_loss: 5.5499e-04 - val_mean_absolute_error: 0.0240
#
# Epoch 00171: val_loss did not improve from 0.00048
# Epoch 172/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.7393e-04 - mean_absolute_error: 0.0245 - val_loss: 4.8469e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00172: val_loss did not improve from 0.00048
# Epoch 173/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.1669e-04 - mean_absolute_error: 0.0248 - val_loss: 5.4163e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00173: val_loss did not improve from 0.00048
# Epoch 174/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.2633e-04 - mean_absolute_error: 0.0255 - val_loss: 4.8275e-04 - val_mean_absolute_error: 0.0208
#
# Epoch 00174: val_loss did not improve from 0.00048
# Epoch 175/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.1609e-04 - mean_absolute_error: 0.0232 - val_loss: 4.9392e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00175: val_loss did not improve from 0.00048
# Epoch 176/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.3702e-04 - mean_absolute_error: 0.0239 - val_loss: 4.9592e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00176: val_loss did not improve from 0.00048
# Epoch 177/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 6.1059e-04 - mean_absolute_error: 0.0245 - val_loss: 4.8675e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00177: val_loss did not improve from 0.00048
# Epoch 178/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.7611e-04 - mean_absolute_error: 0.0244 - val_loss: 4.8876e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00178: val_loss did not improve from 0.00048
# Epoch 179/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.6706e-04 - mean_absolute_error: 0.0263 - val_loss: 4.8886e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00179: val_loss did not improve from 0.00048
# Epoch 180/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4146e-04 - mean_absolute_error: 0.0238 - val_loss: 4.8803e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00180: val_loss did not improve from 0.00048
# Epoch 181/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.8738e-04 - mean_absolute_error: 0.0244 - val_loss: 4.8401e-04 - val_mean_absolute_error: 0.0209
#
# Epoch 00181: val_loss did not improve from 0.00048
# Epoch 182/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.6831e-04 - mean_absolute_error: 0.0243 - val_loss: 4.7763e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00182: val_loss improved from 0.00048 to 0.00048, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 183/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.0710e-04 - mean_absolute_error: 0.0246 - val_loss: 5.1606e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00183: val_loss did not improve from 0.00048
# Epoch 184/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.6826e-04 - mean_absolute_error: 0.0240 - val_loss: 4.8247e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00184: val_loss did not improve from 0.00048
# Epoch 185/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.9816e-04 - mean_absolute_error: 0.0247 - val_loss: 4.8489e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00185: val_loss did not improve from 0.00048
# Epoch 186/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.3877e-04 - mean_absolute_error: 0.0248 - val_loss: 5.0631e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00186: val_loss did not improve from 0.00048
# Epoch 187/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.8971e-04 - mean_absolute_error: 0.0239 - val_loss: 5.7792e-04 - val_mean_absolute_error: 0.0244
#
# Epoch 00187: val_loss did not improve from 0.00048
# Epoch 188/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.8705e-04 - mean_absolute_error: 0.0247 - val_loss: 4.9843e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00188: val_loss did not improve from 0.00048
# Epoch 189/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.5148e-04 - mean_absolute_error: 0.0236 - val_loss: 5.1783e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00189: val_loss did not improve from 0.00048
# Epoch 190/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4300e-04 - mean_absolute_error: 0.0238 - val_loss: 5.0409e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00190: val_loss did not improve from 0.00048
# Epoch 191/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4838e-04 - mean_absolute_error: 0.0236 - val_loss: 4.8712e-04 - val_mean_absolute_error: 0.0216
#
# Epoch 00191: val_loss did not improve from 0.00048
# Epoch 192/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4962e-04 - mean_absolute_error: 0.0241 - val_loss: 4.8551e-04 - val_mean_absolute_error: 0.0208
#
# Epoch 00192: val_loss did not improve from 0.00048
# Epoch 193/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.8482e-04 - mean_absolute_error: 0.0240 - val_loss: 4.7790e-04 - val_mean_absolute_error: 0.0206
#
# Epoch 00193: val_loss did not improve from 0.00048
# Epoch 194/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.2540e-04 - mean_absolute_error: 0.0241 - val_loss: 4.8049e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00194: val_loss did not improve from 0.00048
# Epoch 195/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.6006e-04 - mean_absolute_error: 0.0246 - val_loss: 5.0070e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00195: val_loss did not improve from 0.00048
# Epoch 196/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 4.8419e-04 - mean_absolute_error: 0.0230 - val_loss: 5.1122e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00196: val_loss did not improve from 0.00048
# Epoch 197/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.5000e-04 - mean_absolute_error: 0.0237 - val_loss: 5.1222e-04 - val_mean_absolute_error: 0.0225
#
# Epoch 00197: val_loss did not improve from 0.00048
# Epoch 198/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.3270e-04 - mean_absolute_error: 0.0231 - val_loss: 5.8259e-04 - val_mean_absolute_error: 0.0225
#
# Epoch 00198: val_loss did not improve from 0.00048
# Epoch 199/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.0430e-04 - mean_absolute_error: 0.0230 - val_loss: 4.8210e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00199: val_loss did not improve from 0.00048
# Epoch 200/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4241e-04 - mean_absolute_error: 0.0240 - val_loss: 5.2972e-04 - val_mean_absolute_error: 0.0231
#
# Epoch 00200: val_loss did not improve from 0.00048
# Epoch 201/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.3294e-04 - mean_absolute_error: 0.0252 - val_loss: 5.2703e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00201: val_loss did not improve from 0.00048
# Epoch 202/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.0403e-04 - mean_absolute_error: 0.0235 - val_loss: 5.0475e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00202: val_loss did not improve from 0.00048
# Epoch 203/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.0766e-04 - mean_absolute_error: 0.0251 - val_loss: 4.6826e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00203: val_loss improved from 0.00048 to 0.00047, saving model to results/2021-05-22_^NSEI-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# Epoch 204/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.7389e-04 - mean_absolute_error: 0.0242 - val_loss: 4.7256e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00204: val_loss did not improve from 0.00047
# Epoch 205/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.3434e-04 - mean_absolute_error: 0.0236 - val_loss: 4.8175e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00205: val_loss did not improve from 0.00047
# Epoch 206/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4375e-04 - mean_absolute_error: 0.0237 - val_loss: 4.9435e-04 - val_mean_absolute_error: 0.0206
#
# Epoch 00206: val_loss did not improve from 0.00047
# Epoch 207/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.4225e-04 - mean_absolute_error: 0.0242 - val_loss: 4.7271e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00207: val_loss did not improve from 0.00047
# Epoch 208/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.4422e-04 - mean_absolute_error: 0.0238 - val_loss: 4.7443e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00208: val_loss did not improve from 0.00047
# Epoch 209/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 4.7784e-04 - mean_absolute_error: 0.0234 - val_loss: 4.9987e-04 - val_mean_absolute_error: 0.0208
#
# Epoch 00209: val_loss did not improve from 0.00047
# Epoch 210/10000
# 41/41 [==============================] - 1s 16ms/step - loss: 5.1828e-04 - mean_absolute_error: 0.0239 - val_loss: 4.7355e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00210: val_loss did not improve from 0.00047
# Epoch 211/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.8006e-04 - mean_absolute_error: 0.0241 - val_loss: 4.8032e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00211: val_loss did not improve from 0.00047
# Epoch 212/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.0285e-04 - mean_absolute_error: 0.0231 - val_loss: 5.9979e-04 - val_mean_absolute_error: 0.0255
#
# Epoch 00212: val_loss did not improve from 0.00047
# Epoch 213/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 6.3170e-04 - mean_absolute_error: 0.0256 - val_loss: 5.3693e-04 - val_mean_absolute_error: 0.0215
#
# Epoch 00213: val_loss did not improve from 0.00047
# Epoch 214/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.5450e-04 - mean_absolute_error: 0.0237 - val_loss: 6.8763e-04 - val_mean_absolute_error: 0.0249
#
# Epoch 00214: val_loss did not improve from 0.00047
# Epoch 215/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.6622e-04 - mean_absolute_error: 0.0245 - val_loss: 5.2066e-04 - val_mean_absolute_error: 0.0230
#
# Epoch 00215: val_loss did not improve from 0.00047
# Epoch 216/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 5.6528e-04 - mean_absolute_error: 0.0239 - val_loss: 4.7131e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00216: val_loss did not improve from 0.00047
# Epoch 217/10000
# 41/41 [==============================] - 1s 17ms/step - loss: 4.8117e-04 - mean_absolute_error: 0.0230 - val_loss: 4.8611e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00217: val_loss did not improve from 0.00047
# Epoch 218/10000
# 35/41 [========================>.....] - ETA: 0s - loss: 5.1192e-04 - mean_absolute_error: 0.0233

# %%
import os
print( os.getcwd() )
print( os.listdir() )
print( os.listdir('D:') )
os.chdir('D:')
from google.colab import files
files.download( "mymodel.hdf5" )

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
